# %%
import pandas as pd
df = pd.read_csv('bioactivity_pIC50_v1.csv')
df.head(5)
# Out:
#    Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0           0       CHEMBL133897  ...           6.0  6.124939
# 1           1       CHEMBL336398  ...           5.0  7.000000
# 2           2       CHEMBL131588  ...           5.0  4.301030
# 3           3       CHEMBL130628  ...           5.0  6.522879
# 4           4       CHEMBL130478  ...           6.0  6.096910
#
# [5 rows x 9 columns]

# %%
df['class'] = df['standard_value'].apply(lambda x:'active' if x < 1000 else 'inactive' if x > 10000 else 'intermidate' )
df = df[df['class'] != 'intermidate']
df
# Out:
#       Unnamed: 0 molecule_chembl_id  ...     pIC50     class
# 0              0       CHEMBL133897  ...  6.124939    active
# 1              1       CHEMBL336398  ...  7.000000    active
# 2              2       CHEMBL131588  ...  4.301030  inactive
# 3              3       CHEMBL130628  ...  6.522879    active
# 4              4       CHEMBL130478  ...  6.096910    active
# ...          ...                ...  ...       ...       ...
# 7014        7014      CHEMBL4645476  ...  3.575118  inactive
# 7015        7015      CHEMBL4645659  ...  6.130768    active
# 7016        7016       CHEMBL513063  ...  6.292430    active
# 7017        7017      CHEMBL4640608  ...  3.903090  inactive
# 7018        7018      CHEMBL4173961  ...  4.000000  inactive
#
# [4317 rows x 10 columns]

# %%
df.to_csv('bioactivity_pIC50_class.csv')

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA)

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %%
df_2class = pd.read_csv('bioactivity_data_2class_pIC50.csv')

# %% [markdown]
# 2.1 Frequency plot of the 2 bioactivity classes

# %%
plt.figure(figsize=(5.5, 5.5))
sns.countplot(x='class', data=df_2class, edgecolor='black')
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')
plt.savefig('plot_bioactivity_class.pdf')

# %% [markdown]
# 2.2 Scatter plot of MW versus LogP

# %%
plt.figure(figsize=(5.5, 5.5))
sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='class', size='pIC50',edgecolor='black', alpha=0.7)
plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %% [markdown]
# 2.3 Box plots

# %% [markdown]
# 2.3.1 pIC50 value

# %%
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x = 'class', y = 'pIC50', data = df_2class)
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')
plt.savefig('plot_ic50.pdf')

# %% [markdown]
# 2.3.2 Statistical analysis | Mann-Whitney U Test

# %%
def mannwhitney(descriptor, verbose=False):
    from numpy.random import seed
    from numpy.random import randn
    from scipy.stats import mannwhitneyu
    # seed the random number generator
    seed(1)     
    # actives and inactives
    selection = [descriptor, 'class']
    df = df_2class[selection]
    active = df[df['class'] == 'active']
    active = active[descriptor]
    selection = [descriptor, 'class']
    df = df_2class[selection]
    inactive = df[df['class'] == 'inactive']
    inactive = inactive[descriptor]
    # compare samples
    stat, p = mannwhitneyu(active, inactive)
    #print('Statistics=%.3f, p=%.3f' % (stat, p))
    # interpret
    alpha = 0.05
    if p > alpha:
        interpretation = 'Same distribution (fail to reject H0)'
    else:
        interpretation = 'Different distribution (reject H0)'
    results = pd.DataFrame({'Descriptor':descriptor,
                            'Statistics':stat,
                            'p':p,
                            'alpha':alpha,
                            'Interpretation':interpretation}, index=[0])
    filename = 'mannwhitneyu_' + descriptor + '.csv'
    results.to_csv(filename)
    return results

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics    p  alpha                      Interpretation
# 0      pIC50         0.0  0.0   0.05  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x = 'class', y = 'MW', data = df_2class)
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')
plt.savefig('plot_MW.pdf')

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics  ...  alpha                      Interpretation
# 0         MW   1947235.0  ...   0.05  Different distribution (reject H0)
#
# [1 rows x 5 columns]

# %%
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x = 'class', y = 'LogP', data = df_2class)
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.savefig('plot_LogP.pdf')

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics  ...  alpha                      Interpretation
# 0       LogP   1830555.0  ...   0.05  Different distribution (reject H0)
#
# [1 rows x 5 columns]

# %%
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x = 'class', y = 'NumHDonors', data = df_2class)
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')
plt.savefig('plot_NumHDonors.pdf')

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics  ...  alpha                      Interpretation
# 0  NumHDonors   2188090.0  ...   0.05  Different distribution (reject H0)
#
# [1 rows x 5 columns]

# %%
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x = 'class', y = 'NumHAcceptors', data = df_2class)
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')
plt.savefig('plot_NumHAcceptors.pdf')

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics  ...  alpha                         Interpretation
# 0  NumHAcceptors   2389734.0  ...   0.05  Same distribution (fail to reject H0)
#
# [1 rows x 5 columns]

# %%
df3 = pd.read_csv('bioactivity_data_3class_pIC50.csv')
df3
# Out:
#       Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0              0       CHEMBL133897  ...           6.0  6.124939
# 1              1       CHEMBL336398  ...           5.0  7.000000
# 2              2       CHEMBL131588  ...           5.0  4.301030
# 3              3       CHEMBL130628  ...           5.0  6.522879
# 4              4       CHEMBL130478  ...           6.0  6.096910
# ...          ...                ...  ...           ...       ...
# 7014        7014      CHEMBL4645476  ...           5.0  3.575118
# 7015        7015      CHEMBL4645659  ...           5.0  6.130768
# 7016        7016       CHEMBL513063  ...           4.0  6.292430
# 7017        7017      CHEMBL4640608  ...           NaN  3.903090
# 7018        7018      CHEMBL4173961  ...           NaN  4.000000
#
# [7019 rows x 9 columns]

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2022-02-15 10:05:06--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2022-02-15 10:05:06--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M  --.-KB/s    in 0.1s
#
# 2022-02-15 10:05:07 (167 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# --2022-02-15 10:05:07--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh [following]
# --2022-02-15 10:05:07--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231 [text/plain]
# Saving to: ‘padel.sh’
#
# padel.sh            100%[===================>]     231  --.-KB/s    in 0s
#
# 2022-02-15 10:05:07 (11.5 MB/s) - ‘padel.sh’ saved [231/231]

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
# replace __MACOSX/._PaDEL-Descriptor? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/._PaDEL-Descriptor
# replace PaDEL-Descriptor/MACCSFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
# replace __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
# replace PaDEL-Descriptor/AtomPairs2DFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
# replace __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
# replace PaDEL-Descriptor/EStateFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
# replace __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
# replace PaDEL-Descriptor/Fingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
# replace __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
# replace PaDEL-Descriptor/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/.DS_Store
# replace __MACOSX/PaDEL-Descriptor/._.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
# replace __MACOSX/PaDEL-Descriptor/._license? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._license
# replace PaDEL-Descriptor/KlekotaRothFingerprintCount.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
# replace __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
# replace PaDEL-Descriptor/config? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/config
# replace __MACOSX/PaDEL-Descriptor/._config? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._config
# replace PaDEL-Descriptor/PubchemFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/PubchemFingerprinter.xml
# replace __MACOSX/PaDEL-Descriptor/._PubchemFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._PubchemFingerprinter.xml
# replace PaDEL-Descriptor/ExtendedFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/ExtendedFingerprinter.xml
# replace __MACOSX/PaDEL-Descriptor/._ExtendedFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._ExtendedFingerprinter.xml
# replace PaDEL-Descriptor/KlekotaRothFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprinter.xml
# replace __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprinter.xml
# replace PaDEL-Descriptor/GraphOnlyFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/GraphOnlyFingerprinter.xml
# replace __MACOSX/PaDEL-Descriptor/._GraphOnlyFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._GraphOnlyFingerprinter.xml
# replace PaDEL-Descriptor/SubstructureFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/SubstructureFingerprinter.xml
# replace __MACOSX/PaDEL-Descriptor/._SubstructureFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprinter.xml
# replace PaDEL-Descriptor/Descriptors.xls? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/Descriptors.xls
# replace __MACOSX/PaDEL-Descriptor/._Descriptors.xls? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._Descriptors.xls
# replace __MACOSX/PaDEL-Descriptor/._lib? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._lib
# replace PaDEL-Descriptor/PaDEL-Descriptor.jar? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/PaDEL-Descriptor.jar
# replace __MACOSX/PaDEL-Descriptor/._PaDEL-Descriptor.jar? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._PaDEL-Descriptor.jar
# replace PaDEL-Descriptor/SubstructureFingerprintCount.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/SubstructureFingerprintCount.xml
# replace __MACOSX/PaDEL-Descriptor/._SubstructureFingerprintCount.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprintCount.xml
# replace PaDEL-Descriptor/AtomPairs2DFingerprintCount.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprintCount.xml
# replace __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprintCount.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprintCount.xml
# replace PaDEL-Descriptor/descriptors.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/descriptors.xml
# replace __MACOSX/PaDEL-Descriptor/._descriptors.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/._descriptors.xml
# replace PaDEL-Descriptor/license/lgpl-2.1.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: PaDEL-Descriptor/license/lgpl-2.1.txt
# replace __MACOSX/PaDEL-Descriptor/license/._lgpl-2.1.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl-2.1.txt
# replace PaDEL-Descriptor/license/LICENSE.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace PaDEL-Descriptor/license/LICENSE.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace PaDEL-Descriptor/license/LICENSE.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: PaDEL-Descriptor/license/LICENSE.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._LICENSE.txt
#   inflating: PaDEL-Descriptor/license/README - CDK
#   inflating: __MACOSX/PaDEL-Descriptor/license/._README - CDK
#   inflating: PaDEL-Descriptor/license/lgpl.license
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl.license
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL.jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(4).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(2).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1(1).jar
#   inflating: PaDEL-Descriptor/lib/swing-worker-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._swing-worker-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(3).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(5).jar
#   inflating: PaDEL-Descriptor/lib/jama(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(1).jar
#   inflating: PaDEL-Descriptor/lib/appframework-1.0.3.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._appframework-1.0.3.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(7).jar
#   inflating: PaDEL-Descriptor/lib/vecmath1.2-1.14.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._vecmath1.2-1.14.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(6).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(2).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(4).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(5).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(2).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(3).jar
#   inflating: PaDEL-Descriptor/lib/jama(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(7).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(1).jar
#   inflating: PaDEL-Descriptor/lib/jama(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(3).jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all(1).jar
#   inflating: PaDEL-Descriptor/lib/jama.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama.jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all.jar
#   inflating: PaDEL-Descriptor/lib/jama(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(5).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(7).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(4).jar
#   inflating: PaDEL-Descriptor/lib/cdk-1.4.15.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._cdk-1.4.15.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(6).jar
#   inflating: PaDEL-Descriptor/lib/jama(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(1).jar
#   inflating: PaDEL-Descriptor/lib/guava-17.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._guava-17.0.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(5).jar

# %%
! wget https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# Out:
# --2022-02-15 10:08:03--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 655414 (640K) [text/plain]
# Saving to: ‘acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv.3’
#
# acetylcholinesteras 100%[===================>] 640.05K  --.-KB/s    in 0.006s
#
# 2022-02-15 10:08:03 (101 MB/s) - ‘acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv.3’ saved [655414/655414]

# %%
df3 = pd.read_csv('acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv')
df3
# Out:
#       Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0              0       CHEMBL133897  ...           6.0  6.124939
# 1              1       CHEMBL336398  ...           5.0  7.000000
# 2              2       CHEMBL131588  ...           5.0  4.301030
# 3              3       CHEMBL130628  ...           5.0  6.522879
# 4              4       CHEMBL130478  ...           6.0  6.096910
# ...          ...                ...  ...           ...       ...
# 4690        4690      CHEMBL4293155  ...           3.0  5.612610
# 4691        4691      CHEMBL4282558  ...           3.0  5.595166
# 4692        4692      CHEMBL4281727  ...           3.0  5.419075
# 4693        4693      CHEMBL4292349  ...           5.0  5.460924
# 4694        4694      CHEMBL4278260  ...           4.0  5.555955
#
# [4695 rows x 9 columns]

# %%
! cat molecule.smi | head -5
# Out:
# CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1	CHEMBL133897
# O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1	CHEMBL336398
# CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1	CHEMBL131588
# O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F	CHEMBL130628
# CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C	CHEMBL130478

# %%
! cat molecule.smi | wc -l
# Out:
# 7019

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL133897 in molecule.smi (1/1780).
# Processing CHEMBL336398 in molecule.smi (2/1780).
# Processing CHEMBL130628 in molecule.smi (4/1780). Average speed: 1.74 s/mol.
# Processing CHEMBL131588 in molecule.smi (3/1780). Average speed: 3.13 s/mol.
# Processing CHEMBL130112 in molecule.smi (6/1780). Average speed: 1.05 s/mol.
# Processing CHEMBL130478 in molecule.smi (5/1780). Average speed: 1.39 s/mol.
# Processing CHEMBL130098 in molecule.smi (7/1780). Average speed: 0.93 s/mol.
# Processing CHEMBL337486 in molecule.smi (8/1780). Average speed: 0.82 s/mol.
# Processing CHEMBL336538 in molecule.smi (9/1780). Average speed: 0.73 s/mol.
# Processing CHEMBL131051 in molecule.smi (10/1780). Average speed: 0.70 s/mol.
# Processing CHEMBL341437 in molecule.smi (11/1780). Average speed: 0.63 s/mol.
# Processing CHEMBL335033 in molecule.smi (12/1780). Average speed: 0.62 s/mol.
# Processing CHEMBL122983 in molecule.smi (13/1780). Average speed: 0.58 s/mol.
# Processing CHEMBL338720 in molecule.smi (14/1780). Average speed: 0.57 s/mol.
# Processing CHEMBL339995 in molecule.smi (15/1780). Average speed: 0.56 s/mol.
# Processing CHEMBL131536 in molecule.smi (17/1780). Average speed: 0.51 s/mol.
# Processing CHEMBL335158 in molecule.smi (16/1780). Average speed: 0.54 s/mol.
# Processing CHEMBL334971 in molecule.smi (19/1780). Average speed: 0.49 s/mol.
# Processing CHEMBL106126 in molecule.smi (18/1780). Average speed: 0.51 s/mol.
# Processing CHEMBL336625 in molecule.smi (20/1780). Average speed: 0.47 s/mol.
# Processing CHEMBL130666 in molecule.smi (21/1780). Average speed: 0.47 s/mol.
# Processing CHEMBL134061 in molecule.smi (22/1780). Average speed: 0.47 s/mol.
# Processing CHEMBL133388 in molecule.smi (23/1780). Average speed: 0.47 s/mol.
# Processing CHEMBL130645 in molecule.smi (24/1780). Average speed: 0.44 s/mol.
# Processing CHEMBL335112 in molecule.smi (25/1780). Average speed: 0.42 s/mol.
# Processing CHEMBL133580 in molecule.smi (26/1780). Average speed: 0.42 s/mol.
# Processing CHEMBL336524 in molecule.smi (27/1780). Average speed: 0.42 s/mol.
# Processing CHEMBL336276 in molecule.smi (28/1780). Average speed: 0.42 s/mol.
# Processing CHEMBL334395 in molecule.smi (29/1780). Average speed: 0.41 s/mol.
# Processing CHEMBL131320 in molecule.smi (30/1780). Average speed: 0.40 s/mol.
# Processing CHEMBL339297 in molecule.smi (31/1780). Average speed: 0.39 s/mol.
# Processing CHEMBL337714 in molecule.smi (32/1780). Average speed: 0.39 s/mol.
# Processing CHEMBL122575 in molecule.smi (33/1780). Average speed: 0.39 s/mol.
# Processing CHEMBL130704 in molecule.smi (34/1780). Average speed: 0.37 s/mol.
# Processing CHEMBL46151 in molecule.smi (35/1780). Average speed: 0.37 s/mol.
# Processing CHEMBL296010 in molecule.smi (36/1780). Average speed: 0.37 s/mol.
# Processing CHEMBL54126 in molecule.smi (37/1780). Average speed: 0.36 s/mol.
# Processing CHEMBL295017 in molecule.smi (38/1780). Average speed: 0.36 s/mol.
# Processing CHEMBL297316 in molecule.smi (39/1780). Average speed: 0.35 s/mol.
# Processing CHEMBL65667 in molecule.smi (40/1780). Average speed: 0.34 s/mol.
# Processing CHEMBL431519 in molecule.smi (41/1780). Average speed: 0.34 s/mol.
# Processing CHEMBL14598 in molecule.smi (42/1780). Average speed: 0.34 s/mol.
# Processing CHEMBL296429 in molecule.smi (43/1780). Average speed: 0.34 s/mol.
# Processing CHEMBL154972 in molecule.smi (44/1780). Average speed: 0.33 s/mol.
# Processing CHEMBL152722 in molecule.smi (45/1780). Average speed: 0.33 s/mol.
# Processing CHEMBL544022 in molecule.smi (46/1780). Average speed: 0.33 s/mol.
# Processing CHEMBL156659 in molecule.smi (48/1780). Average speed: 0.32 s/mol.
# Processing CHEMBL349127 in molecule.smi (47/1780). Average speed: 0.33 s/mol.
# Processing CHEMBL45118 in molecule.smi (49/1780). Average speed: 0.32 s/mol.
# Processing CHEMBL47284 in molecule.smi (50/1780). Average speed: 0.32 s/mol.
# Processing CHEMBL542609 in molecule.smi (51/1780). Average speed: 0.31 s/mol.
# Processing CHEMBL154211 in molecule.smi (53/1780). Average speed: 0.31 s/mol.
# Processing CHEMBL155322 in molecule.smi (52/1780). Average speed: 0.31 s/mol.
# Processing CHEMBL1203537 in molecule.smi (54/1780). Average speed: 0.30 s/mol.
# Processing CHEMBL47375 in molecule.smi (56/1780). Average speed: 0.30 s/mol.
# Processing CHEMBL86 in molecule.smi (55/1780). Average speed: 0.30 s/mol.
# Processing CHEMBL542360 in molecule.smi (57/1780). Average speed: 0.29 s/mol.
# Processing CHEMBL345849 in molecule.smi (58/1780). Average speed: 0.29 s/mol.
# Processing CHEMBL154689 in molecule.smi (59/1780). Average speed: 0.28 s/mol.
# Processing CHEMBL346733 in molecule.smi (60/1780). Average speed: 0.28 s/mol.
# Processing CHEMBL416464 in molecule.smi (61/1780). Average speed: 0.28 s/mol.
# Processing CHEMBL47815 in molecule.smi (62/1780). Average speed: 0.28 s/mol.
# Processing CHEMBL347729 in molecule.smi (64/1780). Average speed: 0.27 s/mol.
# Processing CHEMB
1780). Average speed: 0.20 s/mol.
# Processing CHEMBL260308 in molecule.smi (1740/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL407320 in molecule.smi (1741/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL277984 in molecule.smi (1742/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL261384 in molecule.smi (1743/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL270491 in molecule.smi (1744/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL272229 in molecule.smi (1745/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL272230 in molecule.smi (1746/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL273078 in molecule.smi (1747/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL269863 in molecule.smi (1748/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL129542 in molecule.smi (1749/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL502 in molecule.smi (1750/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL1190 in molecule.smi (1751/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL259264 in molecule.smi (1752/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL259482 in molecule.smi (1753/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL129306 in molecule.smi (1754/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL314437 in molecule.smi (1755/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL410915 in molecule.smi (1756/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL345124 in molecule.smi (1757/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL259523 in molecule.smi (1758/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL406645 in molecule.smi (1759/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL497276 in molecule.smi (1760/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL659 in molecule.smi (1761/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL442813 in molecule.smi (1763/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL481657 in molecule.smi (1762/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL416 in molecule.smi (1764/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL51628 in molecule.smi (1766/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL502689 in molecule.smi (1765/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL448060 in molecule.smi (1767/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL303846 in molecule.smi (1768/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL513279 in molecule.smi (1769/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL481658 in molecule.smi (1770/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL461949 in molecule.smi (1771/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL459825 in molecule.smi (1772/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL459826 in molecule.smi (1773/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL496487 in molecule.smi (1774/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL504924 in molecule.smi (1775/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL496259 in molecule.smi (1776/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL496255 in molecule.smi (1777/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL498645 in molecule.smi (1778/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL496488 in molecule.smi (1779/1780). Average speed: 0.20 s/mol.
# Processing CHEMBL659 in molecule.smi (1780/1780). Average speed: 0.20 s/mol.
# Descriptor calculation completed in 5 mins 55.695 secs . Average speed: 0.20 s/mol.

# %%
df3_X = pd.read_csv('descriptors_output.csv')
df3_X
# Out:
#               Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0     CHEMBL336398           1  ...             0             0
# 1     CHEMBL133897           1  ...             0             0
# 2     CHEMBL131588           1  ...             0             0
# 3     CHEMBL130628           1  ...             0             0
# 4     CHEMBL130478           1  ...             0             0
# ...            ...         ...  ...           ...           ...
# 1775  CHEMBL496259           1  ...             0             0
# 1776  CHEMBL496255           1  ...             0             0
# 1777  CHEMBL498645           1  ...             0             0
# 1778  CHEMBL496488           1  ...             0             0
# 1779     CHEMBL659           1  ...             0             0
#
# [1780 rows x 882 columns]

# %%
df3_Y = df3['pIC50']
df3_Y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 4690    5.612610
# 4691    5.595166
# 4692    5.419075
# 4693    5.460924
# 4694    5.555955
# Name: pIC50, Length: 4695, dtype: float64

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3
# Out:
#               Name  PubchemFP0  ...  PubchemFP880     pIC50
# 0     CHEMBL336398         1.0  ...           0.0  6.124939
# 1     CHEMBL133897         1.0  ...           0.0  7.000000
# 2     CHEMBL131588         1.0  ...           0.0  4.301030
# 3     CHEMBL130628         1.0  ...           0.0  6.522879
# 4     CHEMBL130478         1.0  ...           0.0  6.096910
# ...            ...         ...  ...           ...       ...
# 4690           NaN         NaN  ...           NaN  5.612610
# 4691           NaN         NaN  ...           NaN  5.595166
# 4692           NaN         NaN  ...           NaN  5.419075
# 4693           NaN         NaN  ...           NaN  5.460924
# 4694           NaN         NaN  ...           NaN  5.555955
#
# [4695 rows x 883 columns]

# %%
dataset3.to_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %% [markdown]
# ### 4. Regression Models with Random Forest

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df = df.dropna(how='any')

# %%
df.shape
# Out:
# (1780, 884)

# %% [markdown]
# #### 4.1. Input features

# %%
X = df.drop('pIC50', axis=1)
X
# Out:
#       Unnamed: 0          Name  ...  PubchemFP879  PubchemFP880
# 0              0  CHEMBL336398  ...           0.0           0.0
# 1              1  CHEMBL133897  ...           0.0           0.0
# 2              2  CHEMBL131588  ...           0.0           0.0
# 3              3  CHEMBL130628  ...           0.0           0.0
# 4              4  CHEMBL130478  ...           0.0           0.0
# ...          ...           ...  ...           ...           ...
# 1775        1775  CHEMBL496259  ...           0.0           0.0
# 1776        1776  CHEMBL496255  ...           0.0           0.0
# 1777        1777  CHEMBL498645  ...           0.0           0.0
# 1778        1778  CHEMBL496488  ...           0.0           0.0
# 1779        1779     CHEMBL659  ...           0.0           0.0
#
# [1780 rows x 883 columns]

# %%
X = X.drop('Unnamed: 0',axis = 1)
X
# Out:
#               Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0     CHEMBL336398         1.0  ...           0.0           0.0
# 1     CHEMBL133897         1.0  ...           0.0           0.0
# 2     CHEMBL131588         1.0  ...           0.0           0.0
# 3     CHEMBL130628         1.0  ...           0.0           0.0
# 4     CHEMBL130478         1.0  ...           0.0           0.0
# ...            ...         ...  ...           ...           ...
# 1775  CHEMBL496259         1.0  ...           0.0           0.0
# 1776  CHEMBL496255         1.0  ...           0.0           0.0
# 1777  CHEMBL498645         1.0  ...           0.0           0.0
# 1778  CHEMBL496488         1.0  ...           0.0           0.0
# 1779     CHEMBL659         1.0  ...           0.0           0.0
#
# [1780 rows x 882 columns]

# %%
X = X.drop('Name',axis = 1)
X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0            1.0         1.0  ...           0.0           0.0
# 1            1.0         1.0  ...           0.0           0.0
# 2            1.0         1.0  ...           0.0           0.0
# 3            1.0         1.0  ...           0.0           0.0
# 4            1.0         1.0  ...           0.0           0.0
# ...          ...         ...  ...           ...           ...
# 1775         1.0         1.0  ...           0.0           0.0
# 1776         1.0         1.0  ...           0.0           0.0
# 1777         1.0         1.0  ...           0.0           0.0
# 1778         1.0         1.0  ...           0.0           0.0
# 1779         1.0         1.0  ...           0.0           0.0
#
# [1780 rows x 881 columns]

# %% [markdown]
# #### 4.2. Output features

# %%
Y = df.pIC50
Y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 1775    5.920819
# 1776    6.096910
# 1777    8.376751
# 1778    7.886057
# 1779    8.346787
# Name: pIC50, Length: 1780, dtype: float64

# %% [markdown]
# #### 4.3. Let's examine the data dimension

# %%
X.shape
# Out:
# (1780, 881)

# %%
Y.shape
# Out:
# (1780,)

# %% [markdown]
# #### 4.4. Remove low variance **features**

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)

# %%
X.shape
# Out:
# (1780, 128)

# %% [markdown]
# 4.5. Data split (80/20 ratio)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((1424, 128), (1424,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((356, 128), (356,))

# %% [markdown]
# 5. Building a Regression Model using Random Forest

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2
# Out:
# 0.049958783094519954

# %%
Y_pred = model.predict(X_test)

# %% [markdown]
# 4.6. Scatter Plot of Experimental vs Predicted pIC50 Values

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show>
